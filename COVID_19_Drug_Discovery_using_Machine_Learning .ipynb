# %% [markdown]
# # **Drug Discovery using Machine Learning**
#
# Subscribe to Future Omics Bioinformatics made easy
# @Bioinformatics_Made_Easy
# https://www.youtube.com/@Bioinformatics_Made_Easy/videos

# %% [markdown]
# **COVID 19 Drug Discovery using Machine Learning**
#
# Drug discovery for COVID-19 using machine learning (ML) in Python involves several stages, including data collection, feature engineering, model training, and evaluation. ML can be used to predict potential drug candidates by analyzing chemical structures, biological activities, and other relevant data.
#
# **1.Data Collection:**PubChem or ChEMBL: Chemical databases containing information on small molecules, their biological activities, and their interactions with target proteins.
#
# **2.Data Preprocessing**: Once you have the data, the next step is preprocessing:
#
#  **3.Cleaning:** Handle missing or incomplete data.
# Feature extraction: Extract useful features from molecular structures (like SMILES strings or molecular descriptors) using cheminformatics libraries.
# Encoding: Convert molecular data into formats suitable for ML models, e.g., SMILES to molecular embeddings.
#
# **4.Feature Engineering**
# To predict drug efficacy, the molecular features are extracted. You can use:
# Descriptors: Properties of molecules such as molecular weight, logP, topological polar surface area, etc.
#
# **5.Model Training
# Machine learning algorithms can be used to predict the biological activity of molecules against a specific target (e.g., COVID-19 proteins).
#
# You can use: Supervised learning: Train models like Random Forest, Support Vector Machines (SVM), XGBoost, etc

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv("/content/Covid drug bioactive properties.csv")
df.head()
# Out:
#                                               SMILES  MolecularWeight  XLogP  \
# 0  ClC1=CC(NC(=O)CSC2=NC=CC(=N2)C2=CSC(=N2)C2=CC=...            473.4    5.6
# 1  CN1N=C(C=C1C(F)(F)F)C1=CC=C(S1)C1=CC=NC(SCC(=O...            510.0    4.9
# 2  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...            519.1    6.3
# 3  CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...            519.1    6.3
# 4  CC1=NC(=CS1)C1=NC(=CS1)C1=NC(SCC(=O)NC2=CC=C(C...            460.0    4.4
#
#     ExactMass  MonoisotopicMass   TPSA  Complexity  Charge  HBondDonorCount  \
# 0  471.998609        471.998609  121.0         559       0                1
# 1  509.035865        509.035865  126.0         670       0                1
# 2  518.013024        518.013024  175.0         627       0                1
# 3  518.013024        518.013024  175.0         635       0                1
# 4  459.004901        459.004901  162.0         554       0                1
#
#    HBondAcceptorCount  ...  FeatureAcceptorCount3D  FeatureDonorCount3D  \
# 0                   6  ...                       3                    1
# 1                   9  ...                       3                    1
# 2                   8  ...                       3                    1
# 3                   8  ...                       3                    1
# 4                   8  ...                       4                    1
#
#    FeatureAnionCount3D  FeatureCationCount3D  FeatureRingCount3D  \
# 0                    0                     1                   4
# 1                    0                     1                   4
# 2                    0                     1                   4
# 3                    0                     1                   4
# 4                    0                     1                   4
#
#    FeatureHydrophobeCount3D  ConformerModelRMSD3D  EffectiveRotorCount3D  \
# 0                         0                   1.0                    7.0
# 1                         0                   1.2                    8.0
# 2                         1                   1.0                    8.0
# 3                         1                   1.2                    8.0
# 4                         0                   1.0                    7.0
#
#    ConformerCount3D         pIC50
# 0                10  -0.477121255
# 1                10            -1
# 2                10  -1.041392685
# 3                10       BLINDED
# 4                10  -1.146128036
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['SMILES', 'MolecularWeight', 'XLogP', 'ExactMass', 'MonoisotopicMass',
#        'TPSA', 'Complexity', 'Charge', 'HBondDonorCount', 'HBondAcceptorCount',
#        'RotatableBondCount', 'HeavyAtomCount', 'IsotopeAtomCount',
#        'AtomStereoCount', 'DefinedAtomStereoCount', 'UndefinedAtomStereoCount',
#        'BondStereoCount', 'DefinedBondStereoCount', 'CovalentUnitCount',
#        'Volume3D', 'XStericQuadrupole3D', 'YStericQuadrupole3D',
#        'ZStericQuadrupole3D', 'FeatureCount3D', 'FeatureAcceptorCount3D',
#        'FeatureDonorCount3D', 'FeatureAnionCount3D', 'FeatureCationCount3D',
#        'FeatureRingCount3D', 'FeatureHydrophobeCount3D',
#        'ConformerModelRMSD3D', 'EffectiveRotorCount3D', 'ConformerCount3D',
#        'pIC50'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SMILES                    100 non-null    object
#  1   MolecularWeight           100 non-null    float64
#  2   XLogP                     100 non-null    float64
#  3   ExactMass                 100 non-null    float64
#  4   MonoisotopicMass          100 non-null    float64
#  5   TPSA                      100 non-null    float64
#  6   Complexity                100 non-null    int64
#  7   Charge                    100 non-null    int64
#  8   HBondDonorCount           100 non-null    int64
#  9   HBondAcceptorCount        100 non-null    int64
#  10  RotatableBondCount        100 non-null    int64
#  11  HeavyAtomCount            100 non-null    int64
#  12  IsotopeAtomCount          100 non-null    int64
#  13  AtomStereoCount           100 non-null    int64
#  14  DefinedAtomStereoCount    100 non-null    int64
#  15  UndefinedAtomStereoCount  100 non-null    int64
#  16  BondStereoCount           100 non-null    int64
#  17  DefinedBondStereoCount    100 non-null    int64
#  18  CovalentUnitCount         100 non-null    int64
#  19  Volume3D                  100 non-null    float64
#  20  XStericQuadrupole3D       100 non-null    float64
#  21  YStericQuadrupole3D       100 non-null    float64
#  22  ZStericQuadrupole3D       100 non-null    float64
#  23  FeatureCount3D            100 non-null    int64
#  24  FeatureAcceptorCount3D    100 non-null    int64
#  25  FeatureDonorCount3D       100 non-null    int64
#  26  FeatureAnionCount3D       100 non-null    int64
#  27  FeatureCationCount3D      100 non-null    int64
#  28  FeatureRingCount3D        100 non-null    int64
#  29  FeatureHydrophobeCount3D  100 non-null    int64
#  30  ConformerModelRMSD3D      100 non-null    float64
#  31  EffectiveRotorCount3D     100 non-null    float64
#  32  ConformerCount3D          100 non-null    int64
#  33  pIC50                     100 non-null    object
# dtypes: float64(11), int64(21), object(2)
# memory usage: 26.7+ KB

# %%
df['pIC50'].unique()

# 'what does 'BLINDED' mean? anyway remove it.
# Out:
# array(['-0.477121255', '-1', '-1.041392685', 'BLINDED', '-1.146128036',
#        '-1.176091259', '-1.477121255', '-1.602059991', '-1.653212514',
#        '-1.77815125', '-2', '-2.301029996', '-2.397940009',
#        '-2.477121255', '-2.544068044', '-2.602059991', '-2.698970004',
#        '-1.394451681', '-1.324282455', '-2.35545152', '-1.587710965',
#        '-1.158362492', '0.522878745', '0.045757491', '-0.77815125',
#        '-1.079181246', '-1.113943352', '-1.204119983', '-1.397940009',
#        '-0.698970004', '-1.255272505', '-1.301029996', '1.200659451',
#        '1.22184875', '0.681936665', '0.301029996', '0.785156152',
#        '0.156767222', '0.477555766', '0.164943898', '0.906578315',
#        '0.966576245', '-1.501196242', '-1.50623436', '-1.542949849',
#        '-1.003029471', '-1.710371264', '-1.102433706', '-0.071882007',
#        '-0.352182518', '-0.633468456', '-1.072984745', '-1.827369273',
#        '-0.996073654', '-1.14176323', '-0.017033339', '-1.2509077',
#        '-0.450249108', '-1.918606915', '-0.741939078', '-1.600646236',
#        '-0.227886705', '-0.857332496', '-0.973127854', '-1.117602692',
#        '-0.301029996', '0.008773924', '-0.683047038', '0.022276395',
#        '-1.049218023', '-1.371067862', '-1.099335278', '-1.243038049'],
#       dtype=object)

# %%
sum(df['pIC50']=='BLINDED')
# oops!
# Out:
# 9

# %%
df = df[df['pIC50']!='BLINDED']
df
# Out:
#                                                SMILES  MolecularWeight  XLogP  \
# 0   ClC1=CC(NC(=O)CSC2=NC=CC(=N2)C2=CSC(=N2)C2=CC=...            473.4    5.6
# 1   CN1N=C(C=C1C(F)(F)F)C1=CC=C(S1)C1=CC=NC(SCC(=O...            510.0    4.9
# 2   CSC1=C(C(C)=C(S1)C1=NC(C)=CS1)C1=CC=NC(SCC(=O)...            519.1    6.3
# 4   CC1=NC(=CS1)C1=NC(=CS1)C1=NC(SCC(=O)NC2=CC=C(C...            460.0    4.4
# 5   ClC1=CC=C(NC(=O)CSC2=NC=CC(=N2)C2=CC(=NO2)C2=C...            422.9    4.4
# ..                                                ...              ...    ...
# 95      IC1=CC=C2N(CC3=CC4=CC=CC=C4S3)C(=O)C(=O)C2=C1            419.2    4.1
# 96     ClC1=C2C(=O)C(=O)N(CC3=CC4=CC=CC=C4S3)C2=CC=C1            327.8    4.1
# 97  IC1=CC=C2N(C\C=C\C3=CC4=CC=CC=C4S3)C(=O)C(=O)C...            445.3    4.7
# 98  ClC1=CC=C(NC(=O)C2=CC=C(CN3C(=O)C(=O)C4=CC(I)=...            522.7    4.6
# 99  IC1=CC=C2N(CC3=CC=C(S3)C(=O)N3CCCCC3)C(=O)C(=O...            480.3    3.4
#
#      ExactMass  MonoisotopicMass   TPSA  Complexity  Charge  HBondDonorCount  \
# 0   471.998609        471.998609  121.0         559       0                1
# 1   509.035865        509.035865  126.0         670       0                1
# 2   518.013024        518.013024  175.0         627       0                1
# 4   459.004901        459.004901  162.0         554       0                1
# 5   422.060425        422.060425  106.0         529       0                1
# ..         ...               ...    ...         ...     ...              ...
# 95  418.947700        418.947700   65.6         485       0                0
# 96  327.012077        327.012077   65.6         485       0                0
# 97  444.963350        444.963350   65.6         552       0                0
# 98  521.930190        521.930190   94.7         643       0                1
# 99  480.000460        480.000460   85.9         595       0                0
#
#     HBondAcceptorCount  ...  FeatureAcceptorCount3D  FeatureDonorCount3D  \
# 0                    6  ...                       3                    1
# 1                    9  ...                       3                    1
# 2                    8  ...                       3                    1
# 4                    8  ...                       4                    1
# 5                    6  ...                       3                    1
# ..                 ...  ...                     ...                  ...
# 95                   3  ...                       2                    0
# 96                   3  ...                       2                    0
# 97                   3  ...                       2                    0
# 98                   4  ...                       3                    1
# 99                   4  ...                       3                    0
#
#     FeatureAnionCount3D  FeatureCationCount3D  FeatureRingCount3D  \
# 0                     0                     1                   4
# 1                     0                     1                   4
# 2                     0                     1                   4
# 4                     0                     1                   4
# 5                     0                     1                   4
# ..                  ...                   ...                 ...
# 95                    0                     0                   4
# 96                    0                     0                   4
# 97                    0                     0                   4
# 98                    0                     0                   4
# 99                    0                     0                   4
#
#     FeatureHydrophobeCount3D  ConformerModelRMSD3D  EffectiveRotorCount3D  \
# 0                          0                   1.0                    7.0
# 1                          0                   1.2                    8.0
# 2                          1                   1.0                    8.0
# 4                          0                   1.0                    7.0
# 5                          0                   1.0                    7.0
# ..                       ...                   ...                    ...
# 95                         1                   0.6                    2.2
# 96                         0                   0.6                    2.2
# 97                         1                   0.6                    3.2
# 98                         1                   0.8                    5.2
# 99                         1                   0.8                    5.4
#
#     ConformerCount3D         pIC50
# 0                 10  -0.477121255
# 1                 10            -1
# 2                 10  -1.041392685
# 4                 10  -1.146128036
# 5                 10  -1.176091259
# ..               ...           ...
# 95                10   0.022276395
# 96                10  -1.049218023
# 97                10  -1.371067862
# 98                10  -1.099335278
# 99                10  -1.243038049
#
# [91 rows x 34 columns]

# %%
df.describe()
# Out:
#        MolecularWeight      XLogP   ExactMass  MonoisotopicMass        TPSA  \
# count        91.000000  91.000000   91.000000         91.000000   91.000000
# mean        376.399231   3.186813  375.865712        375.821811   99.848352
# std          75.117761   1.564339   74.989076         74.916248   32.142334
# min         212.300000  -0.600000  212.007805        212.007805   34.100000
# 25%         313.000000   2.000000  312.509024        312.509024   83.100000
# 50%         372.200000   3.400000  370.961560        370.961560   96.900000
# 75%         427.500000   4.100000  427.132214        427.132214  120.000000
# max         565.000000   7.300000  563.814325        561.817275  197.000000
#
#        Complexity  Charge  HBondDonorCount  HBondAcceptorCount  \
# count   91.000000    91.0        91.000000           91.000000
# mean   571.582418     0.0         0.670330            5.648352
# std    149.089836     0.0         0.789584            1.695573
# min    242.000000     0.0         0.000000            2.000000
# 25%    472.000000     0.0         0.000000            5.000000
# 50%    554.000000     0.0         0.000000            6.000000
# 75%    669.500000     0.0         1.000000            6.000000
# max    960.000000     0.0         3.000000           10.000000
#
#        RotatableBondCount  ...  FeatureCount3D  FeatureAcceptorCount3D  \
# count           91.000000  ...       91.000000               91.000000
# mean             3.912088  ...        8.395604                3.714286
# std              2.025660  ...        1.679147                1.185896
# min              0.000000  ...        5.000000                1.000000
# 25%              2.000000  ...        7.000000                3.000000
# 50%              4.000000  ...        9.000000                4.000000
# 75%              5.500000  ...        9.000000                4.000000
# max              9.000000  ...       13.000000                7.000000
#
#        FeatureDonorCount3D  FeatureAnionCount3D  FeatureCationCount3D  \
# count            91.000000            91.000000             91.000000
# mean              0.648352             0.230769              0.307692
# std               0.779938             0.496139              0.509734
# min               0.000000             0.000000              0.000000
# 25%               0.000000             0.000000              0.000000
# 50%               0.000000             0.000000              0.000000
# 75%               1.000000             0.000000              1.000000
# max               3.000000             2.000000              2.000000
#
#        FeatureRingCount3D  FeatureHydrophobeCount3D  ConformerModelRMSD3D  \
# count           91.000000                 91.000000             91.000000
# mean             3.230769                  0.263736              0.795604
# std              0.857346                  0.490695              0.217006
# min              2.000000                  0.000000              0.600000
# 25%              3.000000                  0.000000              0.600000
# 50%              3.000000                  0.000000              0.800000
# 75%              4.000000                  0.000000              1.000000
# max              6.000000                  2.000000              1.400000
#
#        EffectiveRotorCount3D  ConformerCount3D
# count              91.000000         91.000000
# mean                4.945055          8.879121
# std                 2.250149          2.678454
# min                 0.000000          1.000000
# 25%                 3.200000         10.000000
# 50%                 5.000000         10.000000
# 75%                 7.000000         10.000000
# max                10.200000         10.000000
#
# [8 rows x 32 columns]

# %%
df = df.dropna(axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 99
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SMILES                    91 non-null     object
#  1   MolecularWeight           91 non-null     float64
#  2   XLogP                     91 non-null     float64
#  3   ExactMass                 91 non-null     float64
#  4   MonoisotopicMass          91 non-null     float64
#  5   TPSA                      91 non-null     float64
#  6   Complexity                91 non-null     int64
#  7   Charge                    91 non-null     int64
#  8   HBondDonorCount           91 non-null     int64
#  9   HBondAcceptorCount        91 non-null     int64
#  10  RotatableBondCount        91 non-null     int64
#  11  HeavyAtomCount            91 non-null     int64
#  12  IsotopeAtomCount          91 non-null     int64
#  13  AtomStereoCount           91 non-null     int64
#  14  DefinedAtomStereoCount    91 non-null     int64
#  15  UndefinedAtomStereoCount  91 non-null     int64
#  16  BondStereoCount           91 non-null     int64
#  17  DefinedBondStereoCount    91 non-null     int64
#  18  CovalentUnitCount         91 non-null     int64
#  19  Volume3D                  91 non-null     float64
#  20  XStericQuadrupole3D       91 non-null     float64
#  21  YStericQuadrupole3D       91 non-null     float64
#  22  ZStericQuadrupole3D       91 non-null     float64
#  23  FeatureCount3D            91 non-null     int64
#  24  FeatureAcceptorCount3D    91 non-null     int64
#  25  FeatureDonorCount3D       91 non-null     int64
#  26  FeatureAnionCount3D       91 non-null     int64
#  27  FeatureCationCount3D      91 non-null     int64
#  28  FeatureRingCount3D        91 non-null     int64
#  29  FeatureHydrophobeCount3D  91 non-null     int64
#  30  ConformerModelRMSD3D      91 non-null     float64
#  31  EffectiveRotorCount3D     91 non-null     float64
#  32  ConformerCount3D          91 non-null     int64
#  33  pIC50                     91 non-null     object
# dtypes: float64(11), int64(21), object(2)
# memory usage: 24.9+ KB

# %% [markdown]
# EDA analysis

# %%
df.describe().T

# Charge, IsotopeAtomCount, DefinedAtomStereoCount, UndefinedBondStereoCount, CovalentUnitCount have to remove
# Out:
#                           count        mean         std         min  \
# MolecularWeight            91.0  376.399231   75.117761  212.300000
# XLogP                      91.0    3.186813    1.564339   -0.600000
# ExactMass                  91.0  375.865712   74.989076  212.007805
# MonoisotopicMass           91.0  375.821811   74.916248  212.007805
# TPSA                       91.0   99.848352   32.142334   34.100000
# Complexity                 91.0  571.582418  149.089836  242.000000
# Charge                     91.0    0.000000    0.000000    0.000000
# HBondDonorCount            91.0    0.670330    0.789584    0.000000
# HBondAcceptorCount         91.0    5.648352    1.695573    2.000000
# RotatableBondCount         91.0    3.912088    2.025660    0.000000
# HeavyAtomCount             91.0   25.054945    4.681791   13.000000
# IsotopeAtomCount           91.0    0.000000    0.000000    0.000000
# AtomStereoCount            91.0    0.131868    0.400244    0.000000
# DefinedAtomStereoCount     91.0    0.000000    0.000000    0.000000
# UndefinedAtomStereoCount   91.0    0.131868    0.400244    0.000000
# BondStereoCount            91.0    0.010989    0.104828    0.000000
# DefinedBondStereoCount     91.0    0.010989    0.104828    0.000000
# CovalentUnitCount          91.0    1.000000    0.000000    1.000000
# Volume3D                   91.0  272.448352   52.520082  155.100000
# XStericQuadrupole3D        91.0   11.658571    3.749035    5.300000
# YStericQuadrupole3D        91.0    3.714286    1.560554    1.210000
# ZStericQuadrupole3D        91.0    1.558352    0.500127    0.600000
# FeatureCount3D             91.0    8.395604    1.679147    5.000000
# FeatureAcceptorCount3D     91.0    3.714286    1.185896    1.000000
# FeatureDonorCount3D        91.0    0.648352    0.779938    0.000000
# FeatureAnionCount3D        91.0    0.230769    0.496139    0.000000
# FeatureCationCount3D       91.0    0.307692    0.509734    0.000000
# FeatureRingCount3D         91.0    3.230769    0.857346    2.000000
# FeatureHydrophobeCount3D   91.0    0.263736    0.490695    0.000000
# ConformerModelRMSD3D       91.0    0.795604    0.217006    0.600000
# EffectiveRotorCount3D      91.0    4.945055    2.250149    0.000000
# ConformerCount3D           91.0    8.879121    2.678454    1.000000
#
#                                  25%        50%         75%         max
# MolecularWeight           313.000000  372.20000  427.500000  565.000000
# XLogP                       2.000000    3.40000    4.100000    7.300000
# ExactMass                 312.509024  370.96156  427.132214  563.814325
# MonoisotopicMass          312.509024  370.96156  427.132214  561.817275
# TPSA                       83.100000   96.90000  120.000000  197.000000
# Complexity                472.000000  554.00000  669.500000  960.000000
# Charge                      0.000000    0.00000    0.000000    0.000000
# HBondDonorCount             0.000000    0.00000    1.000000    3.000000
# HBondAcceptorCount          5.000000    6.00000    6.000000   10.000000
# RotatableBondCount          2.000000    4.00000    5.500000    9.000000
# HeavyAtomCount             21.000000   24.00000   28.000000   37.000000
# IsotopeAtomCount            0.000000    0.00000    0.000000    0.000000
# AtomStereoCount             0.000000    0.00000    0.000000    2.000000
# DefinedAtomStereoCount      0.000000    0.00000    0.000000    0.000000
# UndefinedAtomStereoCount    0.000000    0.00000    0.000000    2.000000
# BondStereoCount             0.000000    0.00000    0.000000    1.000000
# DefinedBondStereoCount      0.000000    0.00000    0.000000    1.000000
# CovalentUnitCount           1.000000    1.00000    1.000000    1.000000
# Volume3D                  233.650000  260.70000  310.600000  388.400000
# XStericQuadrupole3D         9.330000   10.38000   12.635000   22.700000
# YStericQuadrupole3D         2.500000    3.35000    5.145000    8.280000
# ZStericQuadrupole3D         1.130000    1.56000    1.900000    2.960000
# FeatureCount3D              7.000000    9.00000    9.000000   13.000000
# FeatureAcceptorCount3D      3.000000    4.00000    4.000000    7.000000
# FeatureDonorCount3D         0.000000    0.00000    1.000000    3.000000
# FeatureAnionCount3D         0.000000    0.00000    0.000000    2.000000
# FeatureCationCount3D        0.000000    0.00000    1.000000    2.000000
# FeatureRingCount3D          3.000000    3.00000    4.000000    6.000000
# FeatureHydrophobeCount3D    0.000000    0.00000    0.000000    2.000000
# ConformerModelRMSD3D        0.600000    0.80000    1.000000    1.400000
# EffectiveRotorCount3D       3.200000    5.00000    7.000000   10.200000
# ConformerCount3D           10.000000   10.00000   10.000000   10.000000

# %%
# Check the existing columns in your DataFrame
print(df.columns)

# Assuming there's a typo or the column names are slightly different,
# adjust the names in the drop function accordingly.
# For example, if 'Charge' is actually 'charge', use the following:

columns_to_drop = ['Charge', 'IsotopeAtomCount', 'DefinedAtomStereoCount', 'CovalentUnitCount']
# Create a list of columns to drop

existing_columns = df.columns  # Get the existing column names
columns_to_drop = [col for col in columns_to_drop if col in existing_columns]
# Filter the list to include only existing columns

df = df.drop(columns=columns_to_drop, axis=1)
# Use the filtered list to drop columns

df.shape
# Out:
# Index(['SMILES', 'MolecularWeight', 'XLogP', 'ExactMass', 'MonoisotopicMass',
#        'TPSA', 'Complexity', 'HBondDonorCount', 'HBondAcceptorCount',
#        'RotatableBondCount', 'HeavyAtomCount', 'AtomStereoCount',
#        'UndefinedAtomStereoCount', 'BondStereoCount', 'DefinedBondStereoCount',
#        'Volume3D', 'XStericQuadrupole3D', 'YStericQuadrupole3D',
#        'ZStericQuadrupole3D', 'FeatureCount3D', 'FeatureAcceptorCount3D',
#        'FeatureDonorCount3D', 'FeatureAnionCount3D', 'FeatureCationCount3D',
#        'FeatureRingCount3D', 'FeatureHydrophobeCount3D',
#        'ConformerModelRMSD3D', 'EffectiveRotorCount3D', 'ConformerCount3D',
#        'pIC50'],
#       dtype='object')
# (91, 30)

# %%
df.drop(['SMILES'],axis=1,inplace=True)

# %%
# correlation chart

corrmat = df.corr()
corrmat = round(corrmat, 2)
corrmat
# Out:
#                           MolecularWeight  XLogP  ExactMass  MonoisotopicMass  \
# MolecularWeight                      1.00   0.47       1.00              1.00
# XLogP                                0.47   1.00       0.47              0.47
# ExactMass                            1.00   0.47       1.00              1.00
# MonoisotopicMass                     1.00   0.47       1.00              1.00
# TPSA                                 0.44  -0.00       0.44              0.44
# Complexity                           0.71   0.02       0.71              0.71
# HBondDonorCount                      0.34   0.03       0.34              0.34
# HBondAcceptorCount                   0.47  -0.06       0.47              0.47
# RotatableBondCount                   0.67   0.36       0.67              0.67
# HeavyAtomCount                       0.89   0.35       0.89              0.89
# AtomStereoCount                     -0.11  -0.08      -0.10             -0.10
# UndefinedAtomStereoCount            -0.11  -0.08      -0.10             -0.10
# BondStereoCount                      0.10   0.10       0.10              0.10
# DefinedBondStereoCount               0.10   0.10       0.10              0.10
# Volume3D                             0.93   0.44       0.93              0.93
# XStericQuadrupole3D                  0.23   0.25       0.23              0.23
# YStericQuadrupole3D                  0.82   0.35       0.82              0.82
# ZStericQuadrupole3D                  0.47  -0.04       0.47              0.47
# FeatureCount3D                       0.55  -0.10       0.55              0.55
# FeatureAcceptorCount3D               0.12  -0.46       0.12              0.12
# FeatureDonorCount3D                  0.35   0.04       0.35              0.35
# FeatureAnionCount3D                 -0.17  -0.03      -0.17             -0.17
# FeatureCationCount3D                 0.28   0.13       0.28              0.28
# FeatureRingCount3D                   0.41   0.13       0.42              0.42
# FeatureHydrophobeCount3D             0.21   0.39       0.21              0.21
# ConformerModelRMSD3D                 0.70   0.34       0.70              0.70
# EffectiveRotorCount3D                0.72   0.29       0.72              0.72
# ConformerCount3D                     0.28   0.01       0.28              0.28
# pIC50                               -0.25   0.04      -0.25             -0.25
#
#                           TPSA  Complexity  HBondDonorCount  \
# MolecularWeight           0.44        0.71             0.34
# XLogP                    -0.00        0.02             0.03
# ExactMass                 0.44        0.71             0.34
# MonoisotopicMass          0.44        0.71             0.34
# TPSA                      1.00        0.39             0.58
# Complexity                0.39        1.00             0.33
# HBondDonorCount           0.58        0.33             1.00
# HBondAcceptorCount        0.76        0.43             0.41
# RotatableBondCount        0.56        0.42             0.59
# HeavyAtomCount            0.46        0.85             0.37
# AtomStereoCount          -0.14        0.12            -0.00
# UndefinedAtomStereoCount -0.14        0.12            -0.00
# BondStereoCount          -0.11       -0.01            -0.09
# DefinedBondStereoCount   -0.11       -0.01            -0.09
# Volume3D                  0.47        0.80             0.40
# XStericQuadrupole3D      -0.03        0.05            -0.10
# YStericQuadrupole3D       0.45        0.73             0.40
# ZStericQuadrupole3D       0.35        0.55             0.36
# FeatureCount3D            0.68        0.66             0.44
# FeatureAcceptorCount3D    0.47        0.42             0.02
# FeatureDonorCount3D       0.59        0.35             0.98
# FeatureAnionCount3D       0.27       -0.22            -0.20
# FeatureCationCount3D      0.25        0.05             0.20
# FeatureRingCount3D       -0.14        0.50            -0.17
# FeatureHydrophobeCount3D -0.03       -0.03             0.20
# ConformerModelRMSD3D      0.53        0.57             0.56
# EffectiveRotorCount3D     0.63        0.53             0.59
# ConformerCount3D          0.12        0.16             0.15
# pIC50                    -0.30       -0.34            -0.49
#
#                           HBondAcceptorCount  RotatableBondCount  \
# MolecularWeight                         0.47                0.67
# XLogP                                  -0.06                0.36
# ExactMass                               0.47                0.67
# MonoisotopicMass                        0.47                0.67
# TPSA                                    0.76                0.56
# Complexity                              0.43                0.42
# HBondDonorCount                         0.41                0.59
# HBondAcceptorCount                      1.00                0.51
# RotatableBondCount                      0.51                1.00
# HeavyAtomCount                          0.54                0.70
# AtomStereoCount                        -0.16               -0.16
# UndefinedAtomStereoCount               -0.16               -0.16
# BondStereoCount                        -0.17               -0.05
# DefinedBondStereoCount                 -0.17               -0.05
# Volume3D                                0.49                0.76
# XStericQuadrupole3D                     0.13                0.19
# YStericQuadrupole3D                     0.41                0.70
# ZStericQuadrupole3D                     0.27                0.43
# FeatureCount3D                          0.60                0.42
# FeatureAcceptorCount3D                  0.50                0.06
# FeatureDonorCount3D                     0.43                0.61
# FeatureAnionCount3D                     0.20               -0.22
# FeatureCationCount3D                    0.42                0.40
# FeatureRingCount3D                     -0.09                0.02
# FeatureHydrophobeCount3D               -0.31                0.09
# ConformerModelRMSD3D                    0.53                0.86
# EffectiveRotorCount3D                   0.63                0.95
# ConformerCount3D                        0.18                0.51
# pIC50                                  -0.20               -0.32
#
#                           HeavyAtomCount  ...  FeatureAcceptorCount3D  \
# MolecularWeight                     0.89  ...                    0.12
# XLogP                               0.35  ...                   -0.46
# ExactMass                           0.89  ...                    0.12
# MonoisotopicMass                    0.89  ...                    0.12
# TPSA                                0.46  ...                    0.47
# Complexity                          0.85  ...                    0.42
# HBondDonorCount                     0.37  ...                    0.02
# HBondAcceptorCount                  0.54  ...                    0.50
# RotatableBondCount                  0.70  ...                    0.06
# HeavyAtomCount                      1.00  ...                    0.25
# AtomStereoCount                    -0.00  ...                    0.03
# UndefinedAtomStereoCount           -0.00  ...                    0.03
# BondStereoCount                    -0.02  ...                   -0.15
# DefinedBondStereoCount             -0.02  ...                   -0.15
# Volume3D                            0.98  ...                    0.16
# XStericQuadrupole3D                 0.17  ...                   -0.01
# YStericQuadrupole3D                 0.87  ...                    0.14
# ZStericQuadrupole3D                 0.51  ...                    0.18
# FeatureCount3D                      0.68  ...                    0.66
# FeatureAcceptorCount3D              0.25  ...                    1.00
# FeatureDonorCount3D                 0.40  ...                   -0.00
# FeatureAnionCount3D                -0.22  ...                    0.43
# FeatureCationCount3D                0.33  ...                   -0.18
# FeatureRingCount3D                  0.53  ...                   -0.05
# FeatureHydrophobeCount3D            0.02  ...                   -0.31
# ConformerModelRMSD3D                0.80  ...                    0.15
# EffectiveRotorCount3D               0.78  ...                    0.19
# ConformerCount3D                    0.30  ...                   -0.11
# pIC50                              -0.33  ...                    0.03
#
#                           FeatureDonorCount3D  FeatureAnionCount3D  \
# MolecularWeight                          0.35                -0.17
# XLogP                                    0.04                -0.03
# ExactMass                                0.35                -0.17
# MonoisotopicMass                         0.35                -0.17
# TPSA                                     0.59                 0.27
# Complexity                               0.35                -0.22
# HBondDonorCount                          0.98                -0.20
# HBondAcceptorCount                       0.43                 0.20
# RotatableBondCount                       0.61                -0.22
# HeavyAtomCount                           0.40                -0.22
# AtomStereoCount                          0.01                -0.15
# UndefinedAtomStereoCount                 0.01                -0.15
# BondStereoCount                         -0.09                -0.05
# DefinedBondStereoCount                  -0.09                -0.05
# Volume3D                                 0.42                -0.26
# XStericQuadrupole3D                     -0.08                -0.02
# YStericQuadrupole3D                      0.42                -0.27
# ZStericQuadrupole3D                      0.36                -0.09
# FeatureCount3D                           0.44                 0.17
# FeatureAcceptorCount3D                  -0.00                 0.43
# FeatureDonorCount3D                      1.00                -0.25
# FeatureAnionCount3D                     -0.25                 1.00
# FeatureCationCount3D                     0.22                -0.15
# FeatureRingCount3D                      -0.13                -0.47
# FeatureHydrophobeCount3D                 0.16                -0.12
# ConformerModelRMSD3D                     0.59                -0.18
# EffectiveRotorCount3D                    0.62                -0.13
# ConformerCount3D                         0.19                -0.45
# pIC50                                   -0.49                 0.23
#
#                           FeatureCationCount3D  FeatureRingCount3D  \
# MolecularWeight                           0.28                0.41
# XLogP                                     0.13                0.13
# ExactMass                                 0.28                0.42
# MonoisotopicMass                          0.28                0.42
# TPSA                                      0.25               -0.14
# Complexity                                0.05                0.50
# HBondDonorCount                           0.20               -0.17
# HBondAcceptorCount                        0.42               -0.09
# RotatableBondCount                        0.40                0.02
# HeavyAtomCount                            0.33                0.53
# AtomStereoCount                          -0.15                0.10
# UndefinedAtomStereoCount                 -0.15                0.10
# BondStereoCount                          -0.06                0.10
# DefinedBondStereoCount                   -0.06                0.10
# Volume3D                                  0.34                0.50
# XStericQuadrupole3D                       0.17                0.16
# YStericQuadrupole3D                       0.34                0.42
# ZStericQuadrupole3D                       0.11                0.15
# FeatureCount3D                            0.30                0.32
# FeatureAcceptorCount3D                   -0.18               -0.05
# FeatureDonorCount3D                       0.22               -0.13
# FeatureAnionCount3D                      -0.15               -0.47
# FeatureCationCount3D                      1.00                0.17
# FeatureRingCount3D                        0.17                1.00
# FeatureHydrophobeCount3D                 -0.06               -0.01
# ConformerModelRMSD3D                      0.33                0.21
# EffectiveRotorCount3D                     0.38                0.05
# ConformerCount3D                          0.19                0.23
# pIC50                                    -0.28               -0.07
#
#                           FeatureHydrophobeCount3D  ConformerModelRMSD3D  \
# MolecularWeight                               0.21                  0.70
# XLogP                                         0.39                  0.34
# ExactMass                                     0.21                  0.70
# MonoisotopicMass                              0.21                  0.70
# TPSA                                         -0.03                  0.53
# Complexity                                   -0.03                  0.57
# HBondDonorCount                               0.20                  0.56
# HBondAcceptorCount                           -0.31                  0.53
# RotatableBondCount                            0.09                  0.86
# HeavyAtomCount                                0.02                  0.80
# AtomStereoCount                              -0.01                 -0.12
# UndefinedAtomStereoCount                     -0.01                 -0.12
# BondStereoCount                               0.16                 -0.10
# DefinedBondStereoCount                        0.16                 -0.10
# Volume3D                                      0.13                  0.81
# XStericQuadrupole3D                          -0.08                  0.12
# YStericQuadrupole3D                           0.13                  0.74
# ZStericQuadrupole3D                           0.12                  0.45
# FeatureCount3D                                0.09                  0.55
# FeatureAcceptorCount3D                       -0.31                  0.15
# FeatureDonorCount3D                           0.16                  0.59
# FeatureAnionCount3D                          -0.12                 -0.18
# FeatureCationCount3D                         -0.06                  0.33
# FeatureRingCount3D                           -0.01                  0.21
# FeatureHydrophobeCount3D                      1.00                  0.05
# ConformerModelRMSD3D                          0.05                  1.00
# EffectiveRotorCount3D                         0.05                  0.88
# ConformerCount3D                             -0.12                  0.35
# pIC50                                        -0.24                 -0.37
#
#                           EffectiveRotorCount3D  ConformerCount3D  pIC50
# MolecularWeight                            0.72              0.28  -0.25
# XLogP                                      0.29              0.01   0.04
# ExactMass                                  0.72              0.28  -0.25
# MonoisotopicMass                           0.72              0.28  -0.25
# TPSA                                       0.63              0.12  -0.30
# Complexity                                 0.53              0.16  -0.34
# HBondDonorCount                            0.59              0.15  -0.49
# HBondAcceptorCount                         0.63              0.18  -0.20
# RotatableBondCount                         0.95              0.51  -0.32
# HeavyAtomCount                             0.78              0.30  -0.33
# AtomStereoCount                           -0.14             -0.12  -0.09
# UndefinedAtomStereoCount                  -0.14             -0.12  -0.09
# BondStereoCount                           -0.08              0.04  -0.04
# DefinedBondStereoCount                    -0.08              0.04  -0.04
# Volume3D                                   0.80              0.32  -0.35
# XStericQuadrupole3D                        0.13              0.23   0.24
# YStericQuadrupole3D                        0.73              0.28  -0.39
# ZStericQuadrupole3D                        0.51              0.25  -0.30
# FeatureCount3D                             0.54              0.02  -0.33
# FeatureAcceptorCount3D                     0.19             -0.11   0.03
# FeatureDonorCount3D                        0.62              0.19  -0.49
# FeatureAnionCount3D                       -0.13             -0.45   0.23
# FeatureCationCount3D                       0.38              0.19  -0.28
# FeatureRingCount3D                         0.05              0.23  -0.07
# FeatureHydrophobeCount3D                   0.05             -0.12  -0.24
# ConformerModelRMSD3D                       0.88              0.35  -0.37
# EffectiveRotorCount3D                      1.00              0.47  -0.39
# ConformerCount3D                           0.47              1.00   0.07
# pIC50                                     -0.39              0.07   1.00
#
# [29 rows x 29 columns]

# %%
import plotly.express as px
#import plotly.io as pio
#pio.renderers.default = "notebook_connected"

fig = px.imshow(corrmat, text_auto=True, aspect="auto")
fig.show()
# Out:
# <div>                            <div id="926512f4-a727-4ff1-a766-44f5eef29a0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("926512f4-a727-4ff1-a766-44f5eef29a0d")) {                    Plotly.newPlot(                        "926512f4-a727-4ff1-a766-44f5eef29a0d",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["MolecularWeight","XLogP","ExactMass","MonoisotopicMass","TPSA","Complexity","HBondDonorCount","HBondAcceptorCount","RotatableBondCount","HeavyAtomCount","AtomStereoCount","UndefinedAtomStereoCount","BondStereoCount","DefinedBondStereoCount","Volume3D","XStericQuadrupole3D","YStericQuadrupole3D","ZStericQuadrupole3D","FeatureCount3D","FeatureAcceptorCount3D","FeatureDonorCount3D","FeatureAnionCount3D","FeatureCationCount3D","FeatureRingCount3D","FeatureHydrophobeCount3D","ConformerModelRMSD3D","EffectiveRotorCount3D","ConformerCount3D","pIC50"],"y":["MolecularWeight","XLogP","ExactMass","MonoisotopicMass","TPSA","Complexity","HBondDonorCount","HBondAcceptorCount","RotatableBondCount","HeavyAtomCount","AtomStereoCount","UndefinedAtomStereoCount","BondStereoCount","DefinedBondStereoCount","Volume3D","XStericQuadrupole3D","YStericQuadrupole3D","ZStericQuadrupole3D","FeatureCount3D","FeatureAcceptorCount3D","FeatureDonorCount3D","FeatureAnionCount3D","FeatureCationCount3D","FeatureRingCount3D","FeatureHydrophobeCount3D","ConformerModelRMSD3D","EffectiveRotorCount3D","ConformerCount3D","pIC50"],"z":[[1.0,0.47,1.0,1.0,0.44,0.71,0.34,0.47,0.67,0.89,-0.11,-0.11,0.1,0.1,0.93,0.23,0.82,0.47,0.55,0.12,0.35,-0.17,0.28,0.41,0.21,0.7,0.72,0.28,-0.25],[0.47,1.0,0.47,0.47,-0.0,0.02,0.03,-0.06,0.36,0.35,-0.08,-0.08,0.1,0.1,0.44,0.25,0.35,-0.04,-0.1,-0.46,0.04,-0.03,0.13,0.13,0.39,0.34,0.29,0.01,0.04],[1.0,0.47,1.0,1.0,0.44,0.71,0.34,0.47,0.67,0.89,-0.1,-0.1,0.1,0.1,0.93,0.23,0.82,0.47,0.55,0.12,0.35,-0.17,0.28,0.42,0.21,0.7,0.72,0.28,-0.25],[1.0,0.47,1.0,1.0,0.44,0.71,0.34,0.47,0.67,0.89,-0.1,-0.1,0.1,0.1,0.93,0.23,0.82,0.47,0.55,0.12,0.35,-0.17,0.28,0.42,0.21,0.7,0.72,0.28,-0.25],[0.44,-0.0,0.44,0.44,1.0,0.39,0.58,0.76,0.56,0.46,-0.14,-0.14,-0.11,-0.11,0.47,-0.03,0.45,0.35,0.68,0.47,0.59,0.27,0.25,-0.14,-0.03,0.53,0.63,0.12,-0.3],[0.71,0.02,0.71,0.71,0.39,1.0,0.33,0.43,0.42,0.85,0.12,0.12,-0.01,-0.01,0.8,0.05,0.73,0.55,0.66,0.42,0.35,-0.22,0.05,0.5,-0.03,0.57,0.53,0.16,-0.34],[0.34,0.03,0.34,0.34,0.58,0.33,1.0,0.41,0.59,0.37,-0.0,-0.0,-0.09,-0.09,0.4,-0.1,0.4,0.36,0.44,0.02,0.98,-0.2,0.2,-0.17,0.2,0.56,0.59,0.15,-0.49],[0.47,-0.06,0.47,0.47,0.76,0.43,0.41,1.0,0.51,0.54,-0.16,-0.16,-0.17,-0.17,0.49,0.13,0.41,0.27,0.6,0.5,0.43,0.2,0.42,-0.09,-0.31,0.53,0.63,0.18,-0.2],[0.67,0.36,0.67,0.67,0.56,0.42,0.59,0.51,1.0,0.7,-0.16,-0.16,-0.05,-0.05,0.76,0.19,0.7,0.43,0.42,0.06,0.61,-0.22,0.4,0.02,0.09,0.86,0.95,0.51,-0.32],[0.89,0.35,0.89,0.89,0.46,0.85,0.37,0.54,0.7,1.0,-0.0,-0.0,-0.02,-0.02,0.98,0.17,0.87,0.51,0.68,0.25,0.4,-0.22,0.33,0.53,0.02,0.8,0.78,0.3,-0.33],[-0.11,-0.08,-0.1,-0.1,-0.14,0.12,-0.0,-0.16,-0.16,-0.0,1.0,1.0,-0.03,-0.03,-0.02,-0.08,-0.07,-0.0,-0.01,0.03,0.01,-0.15,-0.15,0.1,-0.01,-0.12,-0.14,-0.12,-0.09],[-0.11,-0.08,-0.1,-0.1,-0.14,0.12,-0.0,-0.16,-0.16,-0.0,1.0,1.0,-0.03,-0.03,-0.02,-0.08,-0.07,-0.0,-0.01,0.03,0.01,-0.15,-0.15,0.1,-0.01,-0.12,-0.14,-0.12,-0.09],[0.1,0.1,0.1,0.1,-0.11,-0.01,-0.09,-0.17,-0.05,-0.02,-0.03,-0.03,1.0,1.0,0.01,0.12,-0.01,0.01,-0.09,-0.15,-0.09,-0.05,-0.06,0.1,0.16,-0.1,-0.08,0.04,-0.04],[0.1,0.1,0.1,0.1,-0.11,-0.01,-0.09,-0.17,-0.05,-0.02,-0.03,-0.03,1.0,1.0,0.01,0.12,-0.01,0.01,-0.09,-0.15,-0.09,-0.05,-0.06,0.1,0.16,-0.1,-0.08,0.04,-0.04],[0.93,0.44,0.93,0.93,0.47,0.8,0.4,0.49,0.76,0.98,-0.02,-0.02,0.01,0.01,1.0,0.17,0.89,0.53,0.63,0.16,0.42,-0.26,0.34,0.5,0.13,0.81,0.8,0.32,-0.35],[0.23,0.25,0.23,0.23,-0.03,0.05,-0.1,0 ...

# %% [markdown]
# Maachine Learning for data split

# %%
target = df['pIC50']
features = df.drop(['pIC50'], axis=1)
target.shape, features.shape
# Out:
# ((91,), (91, 28))

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

features_scaled = min_max_scaler.fit_transform(features)
features_scaled
# Out:
# array([[0.7402892 , 0.78481013, 0.73901645, ..., 0.5       , 0.68627451,
#         1.        ],
#        [0.84406011, 0.69620253, 0.84429379, ..., 0.75      , 0.78431373,
#         1.        ],
#        [0.86986107, 0.87341772, 0.86981111, ..., 0.5       , 0.78431373,
#         1.        ],
#        ...,
#        [0.66061809, 0.67088608, 0.66216949, ..., 0.        , 0.31372549,
#         1.        ],
#        [0.88006805, 0.65822785, 0.88094554, ..., 0.25      , 0.50980392,
#         1.        ],
#        [0.75985257, 0.50632911, 0.76176148, ..., 0.25      , 0.52941176,
#         1.        ]])

# %%
y = df['XLogP']
y
# Out:
# 0     5.6
# 1     4.9
# 2     6.3
# 4     4.4
# 5     4.4
#      ...
# 95    4.1
# 96    4.1
# 97    4.7
# 98    4.6
# 99    3.4
# Name: XLogP, Length: 91, dtype: float64

# %%
X = df.drop('XLogP', axis=1)
X
# Out:
#     MolecularWeight   ExactMass  MonoisotopicMass   TPSA  Complexity  \
# 0             473.4  471.998609        471.998609  121.0         559
# 1             510.0  509.035865        509.035865  126.0         670
# 2             519.1  518.013024        518.013024  175.0         627
# 4             460.0  459.004901        459.004901  162.0         554
# 5             422.9  422.060425        422.060425  106.0         529
# ..              ...         ...               ...    ...         ...
# 95            419.2  418.947700        418.947700   65.6         485
# 96            327.8  327.012077        327.012077   65.6         485
# 97            445.3  444.963350        444.963350   65.6         552
# 98            522.7  521.930190        521.930190   94.7         643
# 99            480.3  480.000460        480.000460   85.9         595
#
#     HBondDonorCount  HBondAcceptorCount  RotatableBondCount  HeavyAtomCount  \
# 0                 1                   6                   6              30
# 1                 1                   9                   6              33
# 2                 1                   8                   7              32
# 4                 1                   8                   6              29
# 5                 1                   6                   6              29
# ..              ...                 ...                 ...             ...
# 95                0                   3                   2              22
# 96                0                   3                   2              22
# 97                0                   3                   3              24
# 98                1                   4                   4              28
# 99                0                   4                   3              26
#
#     AtomStereoCount  ...  FeatureAcceptorCount3D  FeatureDonorCount3D  \
# 0                 0  ...                       3                    1
# 1                 0  ...                       3                    1
# 2                 0  ...                       3                    1
# 4                 0  ...                       4                    1
# 5                 0  ...                       3                    1
# ..              ...  ...                     ...                  ...
# 95                0  ...                       2                    0
# 96                0  ...                       2                    0
# 97                0  ...                       2                    0
# 98                0  ...                       3                    1
# 99                0  ...                       3                    0
#
#     FeatureAnionCount3D  FeatureCationCount3D  FeatureRingCount3D  \
# 0                     0                     1                   4
# 1                     0                     1                   4
# 2                     0                     1                   4
# 4                     0                     1                   4
# 5                     0                     1                   4
# ..                  ...                   ...                 ...
# 95                    0                     0                   4
# 96                    0                     0                   4
# 97                    0                     0                   4
# 98                    0                     0                   4
# 99                    0                     0                   4
#
#     FeatureHydrophobeCount3D  ConformerModelRMSD3D  EffectiveRotorCount3D  \
# 0                          0                   1.0                    7.0
# 1                          0                   1.2                    8.0
# 2                          1                   1.0                    8.0
# 4                          0                   1.0                    7.0
# 5                          0                   1.0                    7.0
# ..                       ...                   ...                    ...
# 95                         1                   0.6                    2.2
# 96                         0                   0.6                    2.2
# 97                         1                   0.6                    3.2
# 98                         1                   0.8                    5.2
# 99                         1                   0.8                    5.4
#
#     ConformerCount3D         pIC50
# 0                 10  -0.477121255
# 1                 10            -1
# 2                 10  -1.041392685
# 4                 10  -1.146128036
# 5                 10  -1.176091259
# ..               ...           ...
# 95                10   0.022276395
# 96                10  -1.049218023
# 97                10  -1.371067862
# 98                10  -1.099335278
# 99                10  -1.243038049
#
# [91 rows x 28 columns]

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#     MolecularWeight   ExactMass  MonoisotopicMass   TPSA  Complexity  \
# 85           512.60  512.151826        512.151826   99.3         960
# 21           357.40  357.114713        357.114713   97.7         486
# 25           393.50  393.151098        393.151098   89.4         474
# 7            457.30  456.021452        456.021452  106.0         567
# 4            460.00  459.004901        459.004901  162.0         554
# ..              ...         ...               ...    ...         ...
# 87           448.50  448.145678        448.145678   83.1         829
# 96           327.80  327.012077        327.012077   65.6         485
# 75           308.35  308.083078        308.083078   91.9         554
# 26           379.80  379.016924        379.016924   80.2         443
# 9            471.50  471.067111        471.067111  197.0         955
#
#     HBondDonorCount  HBondAcceptorCount  RotatableBondCount  HeavyAtomCount  \
# 85                0                   7                   5              37
# 21                0                   6                   5              25
# 25                1                   5                   7              28
# 7                 1                   6                   6              30
# 4                 1                   8                   6              29
# ..              ...                 ...                 ...             ...
# 87                0                   5                   4              32
# 96                0                   3                   2              22
# 75                1                   5                   2              21
# 26                1                   8                   4              24
# 9                 3                   9                   7              32
#
#     AtomStereoCount  ...  FeatureAcceptorCount3D  FeatureDonorCount3D  \
# 85                0  ...                       5                    0
# 21                1  ...                       4                    0
# 25                0  ...                       3                    1
# 7                 0  ...                       3                    1
# 4                 0  ...                       4                    1
# ..              ...  ...                     ...                  ...
# 87                0  ...                       4                    0
# 96                0  ...                       2                    0
# 75                1  ...                       4                    1
# 26                0  ...                       2                    1
# 9                 0  ...                       6                    3
#
#     FeatureAnionCount3D  FeatureCationCount3D  FeatureRingCount3D  \
# 85                    0                     1                   6
# 21                    0                     1                   3
# 25                    0                     1                   3
# 7                     0                     1                   4
# 4                     0                     1                   4
# ..                  ...                   ...                 ...
# 87                    0                     0                   5
# 96                    0                     0                   4
# 75                    0                     0                   3
# 26                    0                     1                   2
# 9                     0                     0                   3
#
#     FeatureHydrophobeCount3D  ConformerModelRMSD3D  EffectiveRotorCount3D  \
# 85                         0                   1.2                    6.4
# 21                         0                   0.8                    5.6
# 25                         1                   1.0                    8.0
# 7                          0                   1.0                    7.0
# 4                          0                   1.0                    7.0
# ..                       ...                   ...                    ...
# 87                         0                   0.8                    5.4
# 96                         0                   0.6                    2.2
# 75                         0                   0.6                    3.4
# 26                         0                   0.8                    6.0
# 9                          0                   1.2                    8.0
#
#     ConformerCount3D         pIC50
# 85                10  -0.741939078
# 21                10  -2.477121255
# 25                10  -2.602059991
# 7                 10  -1.176091259
# 4                 10  -1.146128036
# ..               ...           ...
# 87                10  -0.227886705
# 96                10  -1.049218023
# 75                10  -0.352182518
# 26                10  -2.698970004
# 9                 10  -1.602059991
#
# [72 rows x 28 columns]

# %%
X_test
# Out:
#     MolecularWeight   ExactMass  MonoisotopicMass   TPSA  Complexity  \
# 63           278.65  278.009434        278.009434   85.0         347
# 68           475.50  475.141321        475.141321  123.0         810
# 29           338.40  338.115424        338.115424   73.6         613
# 32           278.30  278.094294        278.094294   43.4         533
# 47           365.50  365.086784        365.086784  125.0         544
# 62           278.65  278.009434        278.009434   85.0         347
# 38           317.32  317.047027        317.047027  125.0         565
# 48           413.90  412.972933        412.972933  154.0         578
# 24           424.60  424.193297        424.193297  120.0         773
# 83           412.50  412.145678        412.145678   83.1         730
# 6            525.30  524.008837        524.008837  106.0         687
# 35           565.00  563.814325        561.817275   95.1         777
# 12           434.50  434.104876        434.104876  146.0         836
# 73           296.30  296.046693        296.046693  101.0         521
# 31           276.30  276.078644        276.078644   47.3         471
# 81           398.50  398.130028        398.130028   83.1         702
# 39           331.30  331.062677        331.062677  125.0         592
# 77           323.37  323.093977        323.093977   86.4         577
# 86           436.50  436.109293        436.109293   92.4         803
#
#     HBondDonorCount  HBondAcceptorCount  RotatableBondCount  HeavyAtomCount  \
# 63                0                   5                   3              19
# 68                1                   9                   7              33
# 29                0                   5                   2              25
# 32                0                   3                   0              21
# 47                2                   6                   5              24
# 62                0                   5                   3              19
# 38                0                   6                   2              22
# 48                2                   6                   5              25
# 24                2                   5                   6              30
# 83                0                   5                   4              29
# 6                 1                   9                   6              34
# 35                0                   6                   8              31
# 12                2                   7                   7              31
# 73                1                   6                   2              20
# 31                0                   3                   0              21
# 81                0                   5                   4              28
# 39                0                   6                   2              23
# 77                0                   6                   2              22
# 86                0                   6                   4              31
#
#     AtomStereoCount  ...  FeatureAcceptorCount3D  FeatureDonorCount3D  \
# 63                0  ...                       4                    0
# 68                0  ...                       7                    1
# 29                1  ...                       4                    0
# 32                1  ...                       3                    0
# 47                0  ...                       4                    2
# 62                0  ...                       4                    0
# 38                0  ...                       6                    0
# 48                0  ...                       4                    2
# 24                0  ...                       3                    2
# 83                2  ...                       4                    0
# 6                 0  ...                       3                    1
# 35                0  ...                       4                    0
# 12                0  ...                       5                    2
# 73                0  ...                       5                    1
# 31                0  ...                       3                    0
# 81                0  ...                       4                    0
# 39                0  ...                       6                    0
# 77                0  ...                       4                    0
# 86                0  ...                       5                    0
#
#     FeatureAnionCount3D  FeatureCationCount3D  FeatureRingCount3D  \
# 63                    1                     0                   2
# 68                    0                     1                   4
# 29                    0                     0                   4
# 32                    0                     0                   4
# 47                    0                     0                   3
# 62                    1                     0                   2
# 38                    1                     0                   2
# 48                    0                     0                   3
# 24                    0                     0                   3
# 83                    0                     0                   4
# 6                     0                     1                   4
# 35                    0                     0                   2
# 12                    0                     0                   3
# 73                    0                     0                   3
# 31                    0                     0                   4
# 81                    0                     0                   4
# 39                    1                     0                   2
# 77                    0                     1                   3
# 86                    0                     0                   5
#
#     FeatureHydrophobeCount3D  ConformerModelRMSD3D  EffectiveRotorCount3D  \
# 63                         0                   0.6                    4.0
# 68                         0                   1.2                    8.4
# 29                         0                   0.6                    2.8
# 32                         0                   0.6                    0.6
# 47                         1                   0.8                    5.0
# 62                         0                   0.6                    4.0
# 38                         0                   0.6                    3.0
# 48                         1                   0.8                    6.0
# 24                         1                   1.2                    8.2
# 83                         0                   0.8                    5.4
# 6                          0                   1.0                    8.0
# 35                         0                   1.0                    8.0
# 12                         0                   1.0                    8.0
# 73                         0                   0.6                    3.4
# 31                         0                   0.6                    0.0
# 81                         0                   0.8                    5.4
# 39                         0                   0.6                    3.0
# 77                         0                   0.6                    3.4
# 86                         0                   0.8                    5.4
#
#     ConformerCount3D         pIC50
# 63                10   0.164943898
# 68                10   -1.50623436
# 29                 8  -1.324282455
# 32                 1  -1.158362492
# 47                10            -1
# 62                10   0.477555766
# 38                 4  -1.113943352
# 48                10  -1.176091259
# 24                10  -2.544068044
# 83                10  -0.450249108
# 6                 10  -1.176091259
# 35                10   0.045757491
# 12                10   -1.77815125
# 73                10  -1.102433706
# 31                 1  -1.587710965
# 81                10  -0.017033339
# 39                 4  -1.113943352
# 77                10  -1.072984745
# 86                10  -1.600646236
#
# [19 rows x 28 columns]

# %%
#Linear Regression
#Training the model
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Applying the model to make a prediction
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
y_lr_train_pred
# Out:
# array([3.49109851, 2.68906977, 4.87106645, 4.93810468, 4.16833196,
#        1.93775958, 3.33580365, 2.22610204, 3.56263138, 3.55400663,
#        2.73508738, 4.0651746 , 3.13427485, 2.18000328, 3.92405235,
#        3.49800034, 4.5563849 , 3.54038177, 4.7       , 3.64620119,
#        4.43902041, 4.47010727, 2.76201263, 5.28745878, 3.6891538 ,
#        3.3       , 2.88714504, 1.6       , 2.28978219, 2.29519725,
#        0.15543355, 3.39710004, 0.04527225, 3.79588534, 1.80461168,
#        5.20743304, 4.242647  , 1.44714758, 1.47794235, 0.61030317,
#        2.08903097, 1.25221803, 1.84279595, 3.32651749, 0.77053911,
#        4.36489917, 2.98006561, 1.91808892, 3.71300188, 5.60921234,
#        4.25962205, 4.52331922, 3.30858358, 6.61297261, 5.20755996,
#        2.52503733, 4.1832269 , 2.33172057, 5.89076449, 4.79484977,
#        3.45039726, 3.85559524, 1.2934312 , 3.62125306, 3.24033837,
#        2.43272856, 3.82620197, 3.99552732, 3.71745784, 1.28967445,
#        3.47329221, 0.74288792])

# %%
y_lr_test_pred
# Out:
# array([ 2.88123305,  1.03735623,  2.28790853,  2.64397028,  4.0756812 ,
#         2.82229087,  1.20536902,  3.30308224,  4.5933003 ,  3.69910518,
#         5.99865965,  4.11989386,  1.78079107, -0.40952725,  2.85688337,
#         3.16790537,  1.70722053,  0.63256559,  2.2857912 ])

# %%
#Evaluate model performance
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  0.2625606485590743
# LR R2 (Train):  0.8786972050005133
# LR MSE (Test):  0.8958665546830812
# LR R2 (Test):  0.733293892264067

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     0.262561    0.878697  0.895867  0.733294

# %%
#Random Forest
#Training the model
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %%
#Applying the model to make a prediction
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %%
#Evaluate model performance
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random forest     0.437737    0.472318  0.322556  0.459244
